# %% [markdown]
# # Movie Recommandation system
#
#     The goal of this project to build a Movie Recommandations System, The system will be working on recommanding a movie to the user based on the user's rating, genre of a movie that interest the user, and the timestamp. Providing personlized service to a user results in user satisfaction and successful business.
#
# ## Introduction to the data:
#
#     This dataset describes 5-star rating and free-text tagging activity from MovieLens(http://movielens.org), a movie recommendation service. It contains 100836 ratings across 9742 movies. These data were created by 610 users between March 29, 1996 and September 24, 2018. This dataset was generated on September 26, 2018.
#
#     Users were selected at random for inclusion. All selected users had rated at least 20 movies. No demographic information is included. Each user is represented by an id, and no other information is provided.
#
#     The data are contained in the files `movies.csv`, `ratings.csv`. More details about the contents and use of all these files follows.
#
#     This and other GroupLens data sets are publicly available for download at <http://grouplens.org/datasets/>.

# %% [markdown]
# ### Import the needed Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Datasets
#
# > First Dataset is the Movies Dataset: Movie information is contained in the file `movies.csv`. Each line of this file after the header row represents one movie, and has the following format:
# * movieId
# * title
# * genres
#
# Genres are selected from the following:
#
# * Action
# * Adventure
# * Animation
# * Children's
# * Comedy
# * Crime
# * Documentary
# * Drama
# * Fantasy
# * Film-Noir
# * Horror
# * Musical
# * Mystery
# * Romance
# * Sci-Fi
# * Thriller
# * War
# * Western

# %%
# using pd.read_csv() I am loading the movies dataset
# explored the first five rows of my data using .head() method
movies = pd.read_csv(r"C:\Users\mutha\Downloads\ml-latest-small\ml-latest-small\movies.csv")
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# > Second Dataset is the Ratings Dataset: All ratings are contained in the file `ratings.csv`. Each line of this file after the header row represents one rating of one movie by one user, and has the following format:
# * userId
# * movieId
# * rating
# * timestamp
#
# The lines within this file are ordered first by userId, then, within user, by movieId.
#
# Ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars).
#
# Timestamps represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970.

# %%
# using pd.read_csv() to load the ratings dataset
# explored the top five rows of my dataset using .head()
ratings = pd.read_csv(r"C:\Users\mutha\Downloads\ml-latest-small\ml-latest-small\ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# > Third Dataset is the tags Dataset: All tags are contained in the file `tags.csv`. Each line of this file after the header row represents one tag applied to one movie by one user, and has the following format:
# * userId
# * movieId
# * tag
# * timestamp
#
# Tags are user-generated metadata about movies. Each tag is typically a single word or short phrase. The meaning, value, and purpose of a particular tag is determined by each user.

# %%
tags_df = pd.read_csv(r"C:\Users\mutha\Downloads\ml-latest-small\ml-latest-small\tags.csv")
tags_df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags_df = tags_df.drop(columns=['userId', 'timestamp'])
tags_df.head()
# Out:
#    movieId              tag
# 0    60756            funny
# 1    60756  Highly quotable
# 2    60756     will ferrell
# 3    89774     Boxing story
# 4    89774              MMA

# %% [markdown]
# ### Merge Datasetes:
#     Now I have all of my datasets(movies dataset, ratings dataset and tags dataset) loaded I will go ahead and merge them on to the movie ID using pandas funaction pd.merge(), then print the top five rows to make sure that I have my new data ready to go.

# %%
# here I am merging the two datasets
# Next printed the top five rows
df = pd.merge(movies, ratings, on='movieId')
df = pd.merge(df, tags_df, on='movieId')
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating  timestamp    tag
# 0       1     4.0  964982703  pixar
# 1       1     4.0  964982703  pixar
# 2       1     4.0  964982703    fun
# 3       5     4.0  847434962  pixar
# 4       5     4.0  847434962  pixar

# %%
# Calling info() on my data to learn data insights
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233213 entries, 0 to 233212
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movieId    233213 non-null  int64
#  1   title      233213 non-null  object
#  2   genres     233213 non-null  object
#  3   userId     233213 non-null  int64
#  4   rating     233213 non-null  float64
#  5   timestamp  233213 non-null  int64
#  6   tag        233213 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 12.5+ MB

# %% [markdown]
# We noticed that the type of 'timestamp' column is 'int64' that's because the time stored as Unix time format, which reflects the number of seconds starting from the date of 01/01/1970 the date where this data started to September 26, 2018 the date where the data where generated. next I will be converting 'timestamp' column to human readable format.

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating           timestamp    tag
# 0       1     4.0 2000-07-30 18:45:03  pixar
# 1       1     4.0 2000-07-30 18:45:03  pixar
# 2       1     4.0 2000-07-30 18:45:03    fun
# 3       5     4.0 1996-11-08 06:36:02  pixar
# 4       5     4.0 1996-11-08 06:36:02  pixar

# %% [markdown]
# Next I will extract a year, month and day columns out of timestamps column.

# %%
df['year'] = df['timestamp'].dt.year
df['month'] = df['timestamp'].dt.month
df['day'] = df['timestamp'].dt.day
df = df.drop(columns=['timestamp'])
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating    tag  year  month  day
# 0       1     4.0  pixar  2000      7   30
# 1       1     4.0  pixar  2000      7   30
# 2       1     4.0    fun  2000      7   30
# 3       5     4.0  pixar  1996     11    8
# 4       5     4.0  pixar  1996     11    8

# %%
# Calling .describe() to get a summary of the data
df.describe()
# Out:
#              movieId         userId         rating           year  \
# count  233213.000000  233213.000000  233213.000000  233213.000000
# mean    12319.999443     309.688191       3.966535    2007.939660
# std     28243.919401     178.206387       0.968637       7.167815
# min         1.000000       1.000000       0.500000    1996.000000
# 25%       296.000000     156.000000       3.500000    2002.000000
# 50%      1198.000000     309.000000       4.000000    2008.000000
# 75%      4638.000000     460.000000       5.000000    2015.000000
# max    193565.000000     610.000000       5.000000    2018.000000
#
#                month            day
# count  233213.000000  233213.000000
# mean        6.692007      15.954955
# std         3.351085       8.898575
# min         1.000000       1.000000
# 25%         4.000000       8.000000
# 50%         7.000000      16.000000
# 75%        10.000000      24.000000
# max        12.000000      31.000000

# %%
# Here I am going to check for missing data using the pandas method .isna() followed by .any()
df.isna().any()
# Out:
# movieId    False
# title      False
# genres     False
# userId     False
# rating     False
# tag        False
# year       False
# month      False
# day        False
# dtype: bool

# %%
df.dtypes
# Out:
# movieId      int64
# title       object
# genres      object
# userId       int64
# rating     float64
# tag         object
# year         int32
# month        int32
# day          int32
# dtype: object

# %% [markdown]
# #### Movie Rating Distribution
#
# Next I will explore the distribution of Movie Ratings, earlier we mentioned that the ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars).

# %%
plt.figure(figsize=(8,6))
df['rating'].hist(bins=50)
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.title('Distribution of Movie Ratings')
plt.grid(False)
plt.show()

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
#
# Through this EDA, I aim to gain a comprehensive understanding of the data and prepare it for further analysis, I will create visualizations like histograms, lineplot and heatmap to explore data distribution, and uncover relationships between variables.

# %%
# Heatmap to show the correlation of the data 
plt.figure(figsize=(10, 6))
corr_matrix = df[['userId', 'movieId', 'rating', 'year', 'month', 'day']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### Heatmap
#
# From the above Heatmap we see that 'movieId' has the highest correlation rate of 0.38 with the 'year' column.

# %%
# Next I will be getting the ratings per movie
# To do that I will group my data by title then get the size of it and then sort it in descending order
rating_per_movie = df.groupby('title').size().sort_values(ascending=False)
# Using matplotlib I am going to plot the number of rating per movie
plt.figure(figsize=(8,6))
rating_per_movie.hist(bins=50)
plt.xlabel('Number of Ratings')
plt.ylabel('Number of Movies')
plt.title('Number of Ratings per Movie')
plt.grid(False)
plt.show()

# %%
# Apply log and then square root transformation
log_sqrt_rating_per_movie = np.sqrt(np.log1p(rating_per_movie))

# Plot the transformed data
plt.figure(figsize=(8,6))
log_sqrt_rating_per_movie.hist(bins=50)
plt.xlabel('Square Root of Log of Number of Ratings')
plt.ylabel('Number of Movies')
plt.title('Square Root of Log of Number of Ratings per Movie')
plt.grid(False)
plt.show()

# %%
# Group the data by year and take it's size
ratings_per_year = df.groupby('year').size()
# Line plots are the best to show time series visualisation
ratings_per_year.plot(kind='line')
plt.title('Number of Ratings Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Ratings')
plt.show()

# %%
# Now I will take a look at the top ten rated movies
top_10_rating_movies = df.groupby('title')['rating'].count().sort_values(ascending=False).head(10)
top_10_df = top_10_rating_movies.reset_index()
top_10_df.columns = ['title', 'rating']
plt.figure(figsize=(12,8))
ax = sns.barplot(data=top_10_df, x='rating', y='title')
for container in ax.containers:
    ax.bar_label(container, labels=[f'{v.get_width():.0f}' for v in container], label_type='center', fontsize=12, color='white')
plt.title('Top Ten Rated Movies')
plt.xlabel('Rating')
plt.ylabel('Name of The Movie')
plt.tight_layout()
plt.show()

# %%
# Top ten genres
top_10_genres = df.groupby('genres')['rating'].count().sort_values(ascending=False).head(10)
top_10_genres = top_10_genres.reset_index()
top_10_genres.columns = ['genres', 'rating']
plt.figure(figsize=(10,6))
ax = sns.barplot(data=top_10_genres, x='rating', y='genres')
for container in ax.containers:
    ax.bar_label(container, labels=[f'{v.get_width():.0f}' for v in container], label_type='center', fontsize=10, color='white')
plt.title('Top Rated Genres')
plt.xlabel('Rating')
plt.ylabel('Genres')
plt.tight_layout()
plt.show()

# %%
file_path = "data_wrangling_EDA.csv"
df.to_csv(file_path, index=False)
print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to data_wrangling_EDA.csv

# %% [markdown]
# # Summary
#
# ## Data Wrangling
#
# I began by downloading movie data from the open-source DataLens. Then, I used the pandas function .read_csv to load the three separate datasets—movies.csv, ratings.csv, and tags.csv—into this notebook. My next step was to merge the three datasets on movieID into a single DataFrame.
#
# The next step was to check the data types and correct the timestamp column by converting it to a datetime column. Afterward, I extracted the year, month, and day from the timestamp column.
#
# I checked for NaN values and found that there were no missing values in the data.
#
# Since the rating column will be the dependent variable for the recommendation system, I plotted the distribution of this column to gain insights.
#
# ## EDA
#
# Exploratory Data Analysis (EDA) involves examining the data to gain a deeper understanding of its distributions and correlations. During this phase, I performed several analyses and visualizations:
#
# Heatmap of Numeric Data: I plotted a heatmap to visualize the correlations between the numeric variables in the dataset.
#
# Distribution of the Dependent Column 'Rating': I analyzed the distribution of the rating column. To address skewness and achieve a more normal distribution, I applied square root and logarithmic transformations.
#
# Ratings Over the Years: I plotted the ratings over the years to observe trends and patterns over time.
#
# Highest Rated Movies: I identified and plotted the movies with the highest average ratings.
#
# Top Rated Genres: I analyzed and visualized the genres with the highest average ratings.
#
# These steps helped in uncovering key insights and patterns in the data, providing a solid foundation for developing the recommendation system.
#
# ##  Next step
#
# Next step is data pre-proecessing and data modeling.
